# %%
from tools import FlightSearchTool
from pprint import pprint

# FlightSearchTool._run 호출코드를 작성한다.
flights = FlightSearchTool().run(
  origin_city='인천', # 도시명을 전달하면, city_code로 변환되어 처리된다.
  destination_city='오사카',
  departure_date='2025-05-01',
  adults=1)
pprint(flights)
# Out:
# Using Tool: 항공편 검색 도구
# [{'가격': '69100.00',
#   '도착시간': '2025-05-01T10:05:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T08:00:00',
#   '출발일': '2025-05-01',
#   '출발지': 'ICN',
#   '통화': 'KRW',
#   '편명': '301',
#   '항공사': 'TW'},
#  {'가격': '69100.00',
#   '도착시간': '2025-05-01T18:05:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T15:55:00',
#   '출발일': '2025-05-01',
#   '출발지': 'ICN',
#   '통화': 'KRW',
#   '편명': '305',
#   '항공사': 'TW'},
#  {'가격': '109700.00',
#   '도착시간': '2025-05-01T09:00:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T07:10:00',
#   '출발일': '2025-05-01',
#   '출발지': 'ICN',
#   '통화': 'KRW',
#   '편명': '1301',
#   '항공사': '7C'},
#  {'가격': '109700.00',
#   '도착시간': '2025-05-01T11:00:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T09:10:00',
#   '출발일': '2025-05-01',
#   '출발지': 'ICN',
#   '통화': 'KRW',
#   '편명': '1303',
#   '항공사': '7C'},
#  {'가격': '109700.00',
#   '도착시간': '2025-05-01T18:50:00',
#   '목적지': 'OSA',
#   '출발시간': '2025-05-01T17:00:00',
#   '출발일': '2025-05-01',
# ...

# %%
from tools import HotelSearchTool

# HotelSearchTool._run 호출코드를 작성한다.
hotels = HotelSearchTool().run(
  city_name='오사카',
  check_in_date='2025-05-01',
  check_out_date='2025-05-02',
  adults=1)
pprint(hotels)
# Out:
# Using Tool: 숙소 검색 도구
# [{'check_in': '2025-05-01',
#   'check_out': '2025-05-02',
#   'currency': 'JPY',
#   'hotel_name': 'The Westin Osaka',
#   'room_description': 'Flexible Rate\n'
#                       'Superior King Bed, Floors 24-32, 43sqm, 1\n'
#                       'King, 43sqm/463sqft, Wireless internet,',
#   'total_price': '133125'},
#  {'check_in': '2025-05-01',
#   'check_out': '2025-05-02',
#   'currency': 'JPY',
#   'hotel_name': 'The Ritz-Carlton Osaka',
#   'room_description': 'Flexible Rate\n'
#                       'Superior King Bed, Floors 24-32, 43sqm, 1\n'
#                       'King, 43sqm/463sqft, Wireless internet,',
#   'total_price': '133125'}]

# %%
from tools import NearbyPlacesTool

places = NearbyPlacesTool().run(
  place_name='오사카 도쿄대학',
  radius=1000)
pprint(places)
# Out:
# Using Tool: 인근 장소 검색 도구
# [{'리뷰': [{'내용': '무료로 볼 전시가 많아서 좋았어요.\n'
#                 '저는 장 미로의 전시를 보고 나왔는데 총 3층까지 전시가 이어졌고, 중간에 쉴 장소가 있어서 좋았습니다.',
#           '평점': 5},
#          {'내용': '볼만한 유료전시가 있었으면 좋았을텐데 공공미술관의 특성으로 도쿄도내 일본작가들의 공모전 후 전시가 많았습니다. '
#                 '한 층에 4개 전시관이 있고 색깔과 숫자로 구별되어있어 편리합니다. 마에카와 구니오의 들어가는 미학(?)이 '
#                 '있는 건물도 참 아름답습니다.',
#           '평점': 5},
#          {'내용': '키리코전을 보러 다녀왔습니다. 전시 규모가 크지 않았지만 1시간 정도 둘러보기 좋았습니다. 붉은 벽돌 건물이 '
#                 '예쁘고, 내부 카페에 식사 메뉴도 많아요.',
#           '평점': 5}],
#   '영업시간': ['월요일: 휴무일',
#            '화요일: 오전 9:30 ~ 오후 5:30',
#            '수요일: 오전 9:30 ~ 오후 5:30',
#            '목요일: 오전 9:30 ~ 오후 5:30',
#            '금요일: 오전 9:30 ~ 오후 5:30',
#            '토요일: 오전 9:30 ~ 오후 5:30',
#            '일요일: 오전 9:30 ~ 오후 5:30'],
#   '웹사이트': 'https://www.tobikan.jp/',
#   '이름': '도쿄도 미술관',
#   '전화번호': '03-3823-6921',
#   '주소': '8-36 Uenokōen, Taito City, Tokyo 110-0007 일본',
#   '평점': 4.2},
# ...

# %%
from tools import ExchangeRateTool

exchange_rate = ExchangeRateTool().run(
  from_currency='KRW',
  to_currency='JPY',
  amount=10000)
pprint(exchange_rate)
# Out:
# Using Tool: 환율 도구
# {'conversion_rate': 0.1004,
#  'converted_amount': 1004,
#  'from_currency': 'KRW',
#  'original_amount': 10000,
#  'to_currency': 'JPY'}
